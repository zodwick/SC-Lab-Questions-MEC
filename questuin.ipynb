# %% [markdown]
# question 20

# %%
mix=[[6,3,3],[3,6,1],[1,1,6]]
proteins=[26.2,21,10.1]
carbs=[40.2,44,8,10.1]
fat=[71.2,63.5,82.8]

#all data in order of almond cashew walnut

for i in mix:
    p,c,f=0,0,0
    for e in range(0,3):
        p=p+i[e]*proteins[e]
        c=c+i[e]*carbs[e]
        f=f+i[e]*fat[e]
    print(p,c,f,)

# %% [markdown]
# question 22

# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np


def trapzoid_signal(t, width=2., slope=1., amp=1., offs=0):
    a = slope*width*signal.sawtooth(2*np.pi*t/width, width=0.5)/4.
    a[a>amp/2.] = amp/2.
    a[a<-amp/2.] = -amp/2.
    return a + amp/2. + offs

t = np.linspace(0, 6, 501)
plt.plot(t,trapzoid_signal(t, width=2, slope=2, amp=1.), label="width=2, slope=2, amp=1")
plt.plot(t,trapzoid_signal(t, width=4, slope=1, amp=0.6), label="width=4, slope=1, amp=0.6")

plt.legend( loc=(0.25,1.015))
plt.show()

# %% [markdown]
# SAME QUESTION

# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np

t=np.linspace(0,6,501)
y=signal.sawtooth(2*np.pi*t)
plt.plot(t,y)
plt.show()
# Out:
# C:\Users\91854\AppData\Local\Temp\ipykernel_4384\4010669222.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# q 24

# %%
import sympy as s
t=s.Symbol('t')
exp=(3*t**4)-(40*t**3)+(126*t**2)-9
v=s.diff(exp,t)
a=s.diff(v,t)
l=[0,3,5,7,10]
for i in l:
    print("for t =",i)
    print("velocity is",v.subs(t,i))
    print("acceleration is",a.subs(t,i))
# Out:
# for t = 0
# velocity is 0
# acceleration is 252
# for t = 3
# velocity is 0
# acceleration is -144
# for t = 5
# velocity is -240
# acceleration is -48
# for t = 7
# velocity is 0
# acceleration is 336
# for t = 10
# velocity is 2520
# acceleration is 1452

# %%
import scipy
from numpy import exp
import numpy as np
# def f(x):
    # return 4*x**2+3
f=lambda x:np.exp(x)
i = scipy.integrate.quad(f,0,np.inf)
print(i)
# Out:
# (inf, nan)
# C:\Users\91854\AppData\Local\Temp\ipykernel_4384\2443495849.py:6: RuntimeWarning: overflow encountered in exp
#   f=lambda x:np.exp(x)
# C:\Users\91854\AppData\Local\Temp\ipykernel_4384\2443495849.py:7: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   i = scipy.integrate.quad(f,0,np.inf)

# %% [markdown]
# vector addition

# %%
import numpy as np
a=np.random.rand(12665,22365)
b=np.random.rand(12665,22365)
import time
tic=time.process_time()
c=np.zeros((12665,22365))
for i in range(12665):
    for j in range(22365):
        c[i][j]=a[i][j]+b[i][j]
toc=time.process_time()
print("time taken by for loop is",toc-tic)
tic=time.process_time()
d=a+b
toc=time.process_time()
print("time taken by vectorization is",toc-tic)
# Out:
# time taken by for loop is 136.859375
# time taken by vectorization is 3.609375

# %% [markdown]
# matplotlib

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('_mpl-gallery')


# Creating arrows
x = np.arange(-2, 2.2, 0.2)
y = np.arange(-2, 2.2, 0.2)

# Creating gradient
X, Y = np.meshgrid(x, y)
z = X * np.exp(-X**2-Y**2)
dx, dy = np.gradient(z)

# Creating plot
fig, ax = plt.subplots(figsize =(9, 9))
ax.quiver(X, Y, dx, dy)

ax.xaxis.set_ticks([])
ax.yaxis.set_ticks([])
ax.set_aspect('equal')

# show plot
plt.show()

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt

# Defining subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize =(14, 8))


# first subplot
# Creating arrows
x = np.arange(0, 2.2, 0.2)
y = np.arange(0, 2.2, 0.2)
X, Y = np.meshgrid(x, y)
u = np.cos(X)*Y
v = np.sin(y)*Y
n = -2

# Defining color
color = np.sqrt(((v-n)/2)*2 + ((u-n)/2)*2)

# Creating plot
ax1.quiver(X, Y, u, v, color, alpha = 0.8)
ax1.xaxis.set_ticks([])
ax1.yaxis.set_ticks([])
ax1.axis([-0.2, 2.3, -0.2, 2.3])
ax1.set_aspect('equal')
ax1.set_title('meshgrid function')

# second subplot
# Creating arrows
x = np.arange(-2, 2.2, 0.2)
y = np.arange(-2, 2.2, 0.2)
X, Y = np.meshgrid(x, y)
z = X * np.exp(-X**2 -Y**2)
dx, dy = np.gradient(z)
n = -2

# Defining color
color = np.sqrt(((dx-n)/2)*2 + ((dy-n)/2)*2)

# Creating plot
ax2.quiver(X, Y, dx, dy, color)
ax2.xaxis.set_ticks([])
ax2.yaxis.set_ticks([])
ax2.set_aspect('equal')
ax2.set_title('gradient')


# show figure
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
X= np.random.randint(100,1000)
plt.hist(X, bin=10 , figsize=(10,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 4
#       2 import matplotlib.pyplot as plt
#       3 X= np.random.randint(100,1000)
# ----> 4 plt.hist(X, bin=10 , figsize=(10,10))
#       5 plt.show()
#
# File c:\Users\91854\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2573, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2567 @_copy_docstring_and_deprecators(Axes.hist)
#    2568 def hist(
#    2569         x, bins=None, range=None, density=False, weights=None,
#    2570         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2571         orientation='vertical', rwidth=None, log=False, color=None,
#    2572         label=None, stacked=False, *, data=None, **kwargs):
# -> 2573     return gca().hist(
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import random
M=15
x = np.arange(0, M, 1)
y=random.randint(11, size=(M))
fig,a = plt.subplots(3,1, figsize=(10,12))
a[0].plot(x,y)
a[0].set_title('Line plot')
a[1].stem(x,y)
a[1].set_title('Stem plot')
a[2].bar(x,y)
a[2].set_title('Bar plot')
plt.show()

# %%
x=np.arange(0,6*np.pi,0.1)
cosx=np.cos(x)
d1=np.gradient(cosx,0.1)
plt.plot(x,np.sin(x))
plt.plot(x,d1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
T=20
t = np.arange(0, 40, 0.01) # arguments: start, stop, step
n=1
y1 = ((-1)**n)*1/(2*n+1)*np.cos(2*math.pi*(2*n+1)*t/T)
n=2
y2 = ((-1)**n)*1/(2*n+1)*np.cos(2*math.pi*(2*n+1)*t/T)
n=3
y3 = ((-1)**n)*1/(2*n+1)*np.cos(2*math.pi*(2*n+1)*t/T)
y =(4/math.pi)*(1+y1+y2+y3)
fig,a = plt.subplots(4,1)
a[0].plot(t,y1)
a[0].set_title('First term')
a[1].plot(t,y2)
a[1].set_title('Second term')
a[2].plot(t,y3)
a[2].set_title('third')
a[3].plot(t,y)
a[3].set_title('y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
T=10
t = np.arange(0, 40, 0.01) # arguments: start, stop, step
N=[4,10,100]
fig,a = plt.subplots(3,1)
i=0
for value in N:
    sum=1
sum=1
for n in range(3,value,2):
    k=(n-1)/2
    term = (-1)**k/n*np.cos(2*math.pi*n*t/T)
    sum=sum+term
    y =(4/math.pi)*sum
    a[i].plot(t,y)
    a[i].set_title('y')
    i+=1
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
T=20
t = np.arange(0, 40, 0.01) # arguments: start, stop, step
N=[3,5,10,40]
fig,a = plt.subplots(4,1)
i=0
for value in N:
    sum=1
    print(value)
    for n in range(1, value):
        term = ((-1)**n)*1/(2*n+1)*np.cos(2*math.pi*(2*n+1)*t/T)
        sum=sum+term
        y =(4/math.pi)*(1+sum)
    a[i].plot(t,y)
    a[i].set_title('y')
    i+=1
plt.show()
# Out:
# 3
# 5
# 10
# 40

# %% [markdown]
# PI

# %%
N=[5,10,100,1000,10000]

for value in N:
    sums=1
    for n in range(1,value):
        f=((-1)**n)*1/(2*n+1)
        sums=sums+f
    pi=4*sums
    print(pi)
# Out:
# 3.3396825396825403
# 3.0418396189294032
# 3.1315929035585537
# 3.140592653839794
# 3.1414926535900345

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
T=20
N=[5,10,100,1000,10000]
for value in N:
    sum=1
    for n in range(1, value):
        term = ((-1)**n)*1/(2*n+1)
        sum=sum+term

    pi_value =4*sum
    print(pi_value)
    i+=1
# Out:
# 3.3396825396825403
# 3.0418396189294032
# 3.1315929035585537
# 3.140592653839794
# 3.1414926535900345

# %%
d={
    "apple":"captain",
    "sun":"thor"}

l=['sun','apple','apple','apple','sun']
csun,capple=0,0

for j in l:
        if j=='sun':
             csun+=1
        else:
            capple+=1
            
if csun>capple:
    print(d["sun"])
else:
    print(d["apple"])
# Out:
# captain

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
def model(i,t):
    term = ((-5*math.exp(-t))/r)-(i/(rc))
    return term

r=3
rc=3
t=np.linspace(0,20)
V=5
i0=V/r
plt.style.use('Solarize_Light2')

oi=scipy.integrate.odeint(model,i0,t)
plt.plot(t,oi)
plt.show()

# %%
def modal(u,t):
    return (u[1],math.exp(-t)-2*u[1]-2*u[0])

x0=[0,0]
t=np.linspace(0,10,100)
res=scipy.integrate.odeint(modal,x0,t)
plt.plot(t,res[:,0])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from  scipy.integrate import odeint
b,m,g,l=0.05 , 0.01 , 9.8 , 0.5

def model(x,t):
    return (x[1],(g/l)*np.sin(x[0])-b/m*x[1])

ts=np.arange(0,10,0.1)
u=odeint(model,[0,3],ts)
xs=u[:,0]
plt.plot(ts,xs)
plt.show()

# %% [markdown]
# calculate income from each farm

# %%
#farm 1 2 3
farm=[[141,129,134],[200,130,120],[156,127,149]]
cost=[250,275,325]


for i in farm:
    count=0
    income=0

    for fruit in i:
        income=income+fruit*cost[count]
        count+=1
    print(income)
# Out:
# 114275
# 124750
# 122350
